# %%
import numpy as np
import pandas as pd
file_path = 'E:\practicas\Ejercicios\DIVIPOLA_Departamentos.xlsx'
df = pd.read_excel(file_path, skiprows=9)
df
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\HOLL\AppData\Local\Temp\ipykernel_20772\214319621.py:3: SyntaxWarning: invalid escape sequence '\p'
#   file_path = 'E:\practicas\Ejercicios\DIVIPOLA_Departamentos.xlsx'
#                                                Código  \
# 0                                                  05
# 1                                                  08
# 2                                                  11
# 3                                                  13
# 4                                                  15
# 5                                                  17
# 6                                                  18
# 7                                                  19
# 8                                                  20
# 9                                                  23
# 10                                                 25
# ...
