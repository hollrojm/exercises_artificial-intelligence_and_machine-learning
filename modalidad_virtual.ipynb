# %%
import pandas as pd

modalidad_virtual_data = pd.read_csv('E:\practicas\Ejercicios\ModalidadVirtual.csv')

modalidad_virtual_data
# Out:
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# <>:3: SyntaxWarning: invalid escape sequence '\p'
# C:\Users\HOLL\AppData\Local\Temp\ipykernel_19048\1890677540.py:3: SyntaxWarning: invalid escape sequence '\p'
#   modalidad_virtual_data = pd.read_csv('E:\practicas\Ejercicios\ModalidadVirtual.csv')
#      Unnamed: 0        time                       carrera acepta  \
# 0             0  2020-11-08        Ingeniería de Sistemas     Si
# 1             1  2020-11-08                    Psicología     Si
# 2             2  2020-11-08        Ingeniería de Sistemas     Si
# 3             3  2020-11-08        Ingeniería de Sistemas     Si
# 4             4  2020-11-08        Ingeniería de Sistemas     Si
# ..          ...         ...                           ...    ...
# 217         230  2020-12-10  Gestión Turística y Hotelera     Si
# 218         231  2020-12-11        Ingeniería de Sistemas     No
# 219         232  2020-12-11  Gestión Turística y Hotelera     No
# ...

# %%
filtrar = (modalidad_virtual_data['edad']>35) & (modalidad_virtual_data['carrera'] == 'Ingeniería de Sistemas') & (modalidad_virtual_data['acepta'] == 'Si')
modalidad_virtual_data[filtrar]
# Out:
#      Unnamed: 0        time                 carrera acepta  \
# 4             4  2020-11-08  Ingeniería de Sistemas     Si
# 33           38  2020-11-09  Ingeniería de Sistemas     Si
# 37           43  2020-11-09  Ingeniería de Sistemas     Si
# 55           63  2020-11-09  Ingeniería de Sistemas     Si
# 80           90  2020-11-10  Ingeniería de Sistemas     Si
# 190         202  2020-12-08  Ingeniería de Sistemas     Si
# 197         209  2020-12-08  Ingeniería de Sistemas     Si
#
#                           positivo  \
# 4    Acceso desde cualquier lugar.
# 33               Horario flexible.
# 37   Acceso desde cualquier lugar.
# 55               Horario flexible.
# 80   Acceso desde cualquier lugar.
# 190                     Autonomía.
# 197              Horario flexible.
#
#                                               negativo  edad    sexo trabajo
# 4               Contacto Personal Docente-Estudiantil.    39  Hombre      Sí
# ...

# %%
modalidad_virtual_data
modalidad_virtual_data.head(10)
modalidad_virtual_data.tail(10)
modalidad_virtual_data.info()
modalidad_virtual_data.describe()
modalidad_virtual_data.columns
modalidad_virtual_data.dtypes
modalidad_virtual_data['edad'].unique()
modalidad_virtual_data['edad'].nunique()
modalidad_virtual_data['edad'].value_counts()
modalidad_virtual_data['edad'].value_counts(normalize=True)
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=False)
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=True)
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=True).plot(kind='bar')
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=True).plot(kind='barh')
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=True).plot(kind='pie')
modalidad_virtual_data['edad'].value_counts().sort_index(ascending=True).plot(kind='pie', autopct='%1.1f%%')
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 222 entries, 0 to 221
# Data columns (total 9 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  222 non-null    int64
#  1   time        222 non-null    object
#  2   carrera     222 non-null    object
#  3   acepta      222 non-null    object
#  4   positivo    222 non-null    object
#  5   negativo    222 non-null    object
#  6   edad        222 non-null    int64
#  7   sexo        222 non-null    object
#  8   trabajo     222 non-null    object
# dtypes: int64(2), object(7)
# memory usage: 15.7+ KB
# <Axes: ylabel='count'>
