# %%
import numpy as np
import pandas as pd

data = pd.read_csv('E:/practicas/Ejercicios/tips.csv')
print(data)
print(data.columns)
print(data['sex'].dtype)
print(data.info)
# Out:
#      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# 1         10.34  1.66    Male     No   Sun  Dinner     3
# 2         21.01  3.50    Male     No   Sun  Dinner     3
# 3         23.68  3.31    Male     No   Sun  Dinner     2
# 4         24.59  3.61  Female     No   Sun  Dinner     4
# ..          ...   ...     ...    ...   ...     ...   ...
# 239       29.03  5.92    Male     No   Sat  Dinner     3
# 240       27.18  2.00  Female    Yes   Sat  Dinner     2
# 241       22.67  2.00    Male    Yes   Sat  Dinner     2
# 242       17.82  1.75    Male     No   Sat  Dinner     2
# 243       18.78  3.00  Female     No  Thur  Dinner     2
#
# [244 rows x 7 columns]
# Index(['total_bill', 'tip', 'sex', 'smoker', 'day', 'time', 'size'], dtype='object')
# object
# <bound method DataFrame.info of      total_bill   tip     sex smoker   day    time  size
# 0         16.99  1.01  Female     No   Sun  Dinner     2
# ...

# %%
data.head(10)
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4
# 5       25.29  4.71    Male     No  Sun  Dinner     4
# 6        8.77  2.00    Male     No  Sun  Dinner     2
# 7       26.88  3.12    Male     No  Sun  Dinner     4
# 8       15.04  1.96    Male     No  Sun  Dinner     2
# 9       14.78  3.23    Male     No  Sun  Dinner     2

# %% [markdown]
# Cuantos Elementos hay en total?

# %%
data.size
# Out:
# 1708

# %% [markdown]
# ¿cuales son los nombres de las columnas?

# %%
data.dtypes
# Out:
# total_bill    float64
# tip           float64
# sex            object
# smoker         object
# day            object
# time           object
# size            int64
# dtype: object

# %%
data.shape[0]
# Out:
# 244

# %%
dir(data)
# Out:
# ['T',
#  '_AXIS_LEN',
#  '_AXIS_ORDERS',
#  '_AXIS_TO_AXIS_NUMBER',
#  '_HANDLED_TYPES',
#  '__abs__',
#  '__add__',
#  '__and__',
#  '__annotations__',
#  '__array__',
#  '__array_priority__',
#  '__array_ufunc__',
#  '__arrow_c_stream__',
#  '__bool__',
#  '__class__',
#  '__contains__',
#  '__copy__',
#  '__dataframe__',
#  '__dataframe_consortium_standard__',
#  '__deepcopy__',
#  '__delattr__',
#  '__delitem__',
#  '__dict__',
#  '__dir__',
#  '__divmod__',
#  '__doc__',
#  '__eq__',
#  '__finalize__',
#  '__firstlineno__',
#  '__floordiv__',
#  '__format__',
#  '__ge__',
#  '__getattr__',
#  '__getattribute__',
#  '__getitem__',
#  '__getstate__',
#  '__gt__',
#  '__hash__',
#  '__iadd__',
#  '__iand__',
#  '__ifloordiv__',
#  '__imod__',
#  '__imul__',
#  '__init__',
#  '__init_subclass__',
#  '__invert__',
#  '__ior__',
#  '__ipow__',
#  '__isub__',
#  '__iter__',
#  '__itruediv__',
#  '__ixor__',
#  '__le__',
#  '__len__',
#  '__lt__',
#  '__matmul__',
#  '__mod__',
# ...

# %%
data.describe( )
# Out:
#        total_bill         tip        size
# count  244.000000  244.000000  244.000000
# mean    19.785943    2.998279    2.569672
# std      8.902412    1.383638    0.951100
# min      3.070000    1.000000    1.000000
# 25%     13.347500    2.000000    2.000000
# 50%     17.795000    2.900000    2.000000
# 75%     24.127500    3.562500    3.000000
# max     50.810000   10.000000    6.000000

# %%
data.std(numeric_only=True)
# Out:
# total_bill    8.902412
# tip           1.383638
# size          0.951100
# dtype: float64

# %%
data.head(50).mean(numeric_only=True)
# Out:
# total_bill    19.2312
# tip            3.0896
# size           2.7000
# dtype: float64

# %%
data_frame = {
    'Nombre': ['Ana', 'Luis', 'Carlos'],
    'Edad': [23, 30, 25],
    'Ciudad': ['Madrid', 'Barcelona','Valencia']
}
df = pd.DataFrame(data_frame)
print(df)
# Out:
#    Nombre  Edad     Ciudad
# 0     Ana    23     Madrid
# 1    Luis    30  Barcelona
# 2  Carlos    25   Valencia

# %% [markdown]
# mostrar columna

# %%
df['Nombre']
# Out:
# 0       Ana
# 1      Luis
# 2    Carlos
# Name: Nombre, dtype: object

# %%
df[df['Edad'] > 25]
# Out:
#   Nombre  Edad     Ciudad
# 1   Luis    30  Barcelona

# %%
df['Ciudad']
# Out:
# 0       Madrid
# 1    Barcelona
# 2     Valencia
# Name: Ciudad, dtype: object

# %% [markdown]
# Agregar una columna

# %%
df['Puntaje'] = [8.5,9.1,7.3]
print(df)
# Out:
#    Nombre  Edad     Ciudad  Puntaje
# 0     Ana    23     Madrid      8.5
# 1    Luis    30  Barcelona      9.1
# 2  Carlos    25   Valencia      7.3

# %% [markdown]
# Crea un DataFrame con 10 filas y4 columnas: nombre, edad, ciudad, sexo Luego:
# •	Filtra las personas mayores de 25.
# •	Muestra solo la columna ciudad
# •	Agrega una columna "profesión".
# •	Muestras solo las personas de sexo femenino
# •	Agrega una columna dirección
# •	Filtra solo las  persona menores de 20
# •	Ordena el DataFrame por edad de mayor a menor.

# %%
data_frame_eje ={
    'nombre':['Camila','Adriana','Ximena','Fabio','Emilio','Maria','Firulais','Resurección','Panchito','Andrea'],
    'edad':[11,34,40,42,7,25,3,2,50,20],
    'ciudad':['Bogota','Cali','Medellin','Barranquilla','Boyacá','Bucaramanga','Cartagena','Santa Marta','Villavicencio','Cucuta'],
    'sexo':['Femenino','Femenino','Femenino','Masculino','Masculino','Femenino','Maculino','femenino','Masculino', 'Femenino']  
}
df = pd.DataFrame(data_frame_eje)

# %% [markdown]
# #Filtrar las personas que tienen mas de 25 años

# %%
df[df['edad']>25]
# Out:
#      nombre  edad         ciudad       sexo
# 1   Adriana    34           Cali   Femenino
# 2    Ximena    40       Medellin   Femenino
# 3     Fabio    42   Barranquilla  Masculino
# 8  Panchito    50  Villavicencio  Masculino

# %% [markdown]
# #Muestra solo la columna ciudad

# %%
df['ciudad']
# Out:
# 0           Bogota
# 1             Cali
# 2         Medellin
# 3     Barranquilla
# 4           Boyacá
# 5      Bucaramanga
# 6        Cartagena
# 7      Santa Marta
# 8    Villavicencio
# 9           Cucuta
# Name: ciudad, dtype: object

# %% [markdown]
# #Agrega una columna "profesión".

# %%
df['profesión'] = ['Ingeniera','Abogada','Medico','Ingeniero','Abogado','Medico','Ingeniero','Abogado','Medico','Ingeniero']
print(df)
# Out:
#         nombre  edad         ciudad       sexo  profesión
# 0       Camila    11         Bogota   Femenino  Ingeniera
# 1      Adriana    34           Cali   Femenino    Abogada
# 2       Ximena    40       Medellin   Femenino     Medico
# 3        Fabio    42   Barranquilla  Masculino  Ingeniero
# 4       Emilio     7         Boyacá  Masculino    Abogado
# 5        Maria    25    Bucaramanga   Femenino     Medico
# 6     Firulais     3      Cartagena   Maculino  Ingeniero
# 7  Resurección     2    Santa Marta   femenino    Abogado
# 8     Panchito    50  Villavicencio  Masculino     Medico
# 9       Andrea    20         Cucuta   Femenino  Ingeniero

# %% [markdown]
# #Muestras solo las personas de sexo femenino

# %%
df[df['sexo'] == 'Femenino']
# Out:
#     nombre  edad       ciudad      sexo  profesión
# 0   Camila    11       Bogota  Femenino  Ingeniera
# 1  Adriana    34         Cali  Femenino    Abogada
# 2   Ximena    40     Medellin  Femenino     Medico
# 5    Maria    25  Bucaramanga  Femenino     Medico
# 9   Andrea    20       Cucuta  Femenino  Ingeniero

# %%
df['direccion'] = ['av siempre viva','av 80','av 100','av 200','av 300','av 400','av 500','av 600','av 700','av 800']
print(df)
# Out:
#         nombre  edad         ciudad       sexo  profesión        direccion
# 0       Camila    11         Bogota   Femenino  Ingeniera  av siempre viva
# 1      Adriana    34           Cali   Femenino    Abogada            av 80
# 2       Ximena    40       Medellin   Femenino     Medico           av 100
# 3        Fabio    42   Barranquilla  Masculino  Ingeniero           av 200
# 4       Emilio     7         Boyacá  Masculino    Abogado           av 300
# 5        Maria    25    Bucaramanga   Femenino     Medico           av 400
# 6     Firulais     3      Cartagena   Maculino  Ingeniero           av 500
# 7  Resurección     2    Santa Marta   femenino    Abogado           av 600
# 8     Panchito    50  Villavicencio  Masculino     Medico           av 700
# 9       Andrea    20         Cucuta   Femenino  Ingeniero           av 800

# %%
df[df['edad'] < 20]
# Out:
#         nombre  edad       ciudad       sexo  profesión        direccion
# 0       Camila    11       Bogota   Femenino  Ingeniera  av siempre viva
# 4       Emilio     7       Boyacá  Masculino    Abogado           av 300
# 6     Firulais     3    Cartagena   Maculino  Ingeniero           av 500
# 7  Resurección     2  Santa Marta   femenino    Abogado           av 600

# %%
df.sort_values(by='edad', ascending=False)
# Out:
#         nombre  edad         ciudad       sexo  profesión        direccion
# 8     Panchito    50  Villavicencio  Masculino     Medico           av 700
# 3        Fabio    42   Barranquilla  Masculino  Ingeniero           av 200
# 2       Ximena    40       Medellin   Femenino     Medico           av 100
# 1      Adriana    34           Cali   Femenino    Abogada            av 80
# 5        Maria    25    Bucaramanga   Femenino     Medico           av 400
# 9       Andrea    20         Cucuta   Femenino  Ingeniero           av 800
# 0       Camila    11         Bogota   Femenino  Ingeniera  av siempre viva
# 4       Emilio     7         Boyacá  Masculino    Abogado           av 300
# 6     Firulais     3      Cartagena   Maculino  Ingeniero           av 500
# 7  Resurección     2    Santa Marta   femenino    Abogado           av 600
